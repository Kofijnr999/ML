# %%
#Handling values
import pandas as pd
import numpy as np

# %%
#Visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#load dataset
ins=pd.read_csv('K:/python/[FreeTutorials.Eu] Udemy - Python for Data Science and Machine Learning Bootcamp/dS/projects/regression/datasets/insurance (1).csv')
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.set(style='darkgrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(ins['charges'], kde = True, color = 'g')
plt.title('Distribution of Charges')
# Out:
# C:\Users\Buabeng\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Charges')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.distplot(np.log10(ins['charges']), kde = True, color = 'b' )
# Out:
# C:\Users\Buabeng\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
charges = ins['charges'].groupby(ins.region).sum().sort_values(ascending = True)
t, ax = plt.subplots(1, 1, figsize=(8, 6))
ax = sns.barplot(charges.head(), charges.head().index, palette='Blues')
# Out:
# C:\Users\Buabeng\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# plt.figure(figsize=(12,8))
# plt.style.use('ggplot')
# s=ins['region'].value_counts()
# plt.pie(s,explode=(0.1,0.1,0.1,0.1))

# %%
x,y = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='sex', data=ins, palette='cool')

# %%
f, ax = plt.subplots(1,1, figsize=(12,8))
ax = sns.barplot(x = 'region', y = 'charges',
                 hue='smoker', data=ins, palette='Reds_r')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='children', data=ins, palette='Set1')

# %%
ins.plot.area(subplots=True,figsize=(10,5))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.lmplot(x = 'age', y = 'charges', data=ins, hue='smoker', palette='Set1')
ax = sns.lmplot(x = 'bmi', y = 'charges', data=ins, hue='smoker', palette='Set2')
ax = sns.lmplot(x = 'children', y = 'charges', data=ins, hue='smoker', palette='Set3')

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.violinplot(x = 'children', y = 'charges', data=ins,
                 orient='v', hue='smoker', palette='inferno')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='region',data=ins)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='sex',y='charges',data=ins)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
plt.figure(figsize=(10,5))
plt.title('SMEX')
sns.countplot(x='sex',data=ins)
# Out:
# <AxesSubplot:title={'center':'SMEX'}, xlabel='sex', ylabel='count'>

# %%
ins['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.title('SMOKERS')
sns.countplot(x='smoker',data=ins)
# Out:
# <AxesSubplot:title={'center':'SMOKERS'}, xlabel='smoker', ylabel='count'>

# %%
sns.displot(x='age',data=ins,hue='region',bins=10)

# %%
sns.displot(x='age',data=ins,hue='smoker')

# %%
ins['children'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(ins,x_vars=['age','bmi','children','sex'],y_vars='charges')

# %%
sns.jointplot(x='age',y='charges',data=ins,hue='sex')

# %%
sns.jointplot(x='age',y='charges',data=ins,hue='smoker')

# %%
sns.jointplot(x='age',y='charges',data=ins,hue='region')

# %%
sns.jointplot(x='bmi',y='charges',data=ins,hue='sex')

# %%
sns.jointplot(x='bmi',y='charges',data=ins,hue='region')

# %%
sns.jointplot(x='bmi',y='charges',data=ins,hue='smoker')

# %%
ins['age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
ins['bmi'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
ins[['sex', 'smoker', 'region']] = ins[['sex', 'smoker', 'region']].astype('category')
ins.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
##Converting category labels into numerical using LabelEncoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(ins.sex.drop_duplicates())
ins.sex = label.transform(ins.sex)
label.fit(ins.smoker.drop_duplicates())
ins.smoker = label.transform(ins.smoker)
label.fit(ins.region.drop_duplicates())
ins.region = label.transform(ins.region)
ins.dtypes
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.heatmap(ins.corr(), annot=True, cmap='cool')

# %%
x = ins.drop(['charges'], axis = 1)
y = ins['charges']

# %%
from sklearn.model_selection import train_test_split as holdout

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.5,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(x_test.shape, 'and',y_test.shape)
# Out:
# (669,) and (669,)

# %%
print(lm.intercept_)
print('\n')
print(lm.coef_)
# print('\n')
# print(lm.score(x_test, y_test))
# Out:
# [41.52916887 30.20639761  0.82668632  0.12087784]
#
#
# [[ 3.48589524e-02 -9.83215555e-02 -1.28507627e-01  1.70163247e+00]
#  [ 2.10558308e-02 -6.68845582e-03  3.00925411e-02 -1.26553632e+00]
#  [ 5.49511349e-03  1.58720407e-03 -3.39162232e-02  3.31428011e-02]
#  [ 2.86143711e-04  1.68828906e-03  5.51408798e-04 -2.19736353e-02]]

# %%
b=x_test.values
c=b.reshape(-1,1)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.preprocessing import PolynomialFeatures
x = ins.drop(['charges', 'sex', 'region'], axis = 1)
y = ins.charges
pol = PolynomialFeatures (degree = 2)
x_pol = pol.fit_transform(x)
x_train, x_test, y_train, y_test = holdout(x_pol, y, test_size=0.2, random_state=0)
Pol_reg = LinearRegression()
Pol_reg.fit(x_train, y_train)
y_train_pred = Pol_reg.predict(x_train)
y_test_pred = Pol_reg.predict(x_test)
print(Pol_reg.intercept_)
print(Pol_reg.coef_)
print(Pol_reg.score(x_test, y_test))
# Out:
# -5325.881705253369
# [ 0.00000000e+00 -4.01606591e+01  5.23702019e+02  8.52025026e+02
#  -9.52698471e+03  3.04430186e+00  1.84508369e+00  6.01720286e+00
#   4.20849790e+00 -9.38983382e+00  3.81612289e+00  1.40840670e+03
#  -1.45982790e+02 -4.46151855e+02 -9.52698471e+03]
# 0.8812595703345227
