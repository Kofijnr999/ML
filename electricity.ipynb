# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Elec=pd.read_csv('c:/New folder (2)/csv/Electricity_Production_By_Source.csv')
Africa=Elec[Elec['Entity']=='Africa']
Africa.drop()
# Out:
#     Entity Code  Year  Electricity from coal (TWh)  \
# 20  Africa  NaN  1985                   139.514336
# 21  Africa  NaN  1986                   142.078250
# 22  Africa  NaN  1987                   152.227476
# 23  Africa  NaN  1988                   152.448726
# 24  Africa  NaN  1989                   157.210628
# 25  Africa  NaN  1990                   164.673535
# 26  Africa  NaN  1991                   164.785978
# 27  Africa  NaN  1992                   165.420407
# 28  Africa  NaN  1993                   175.962405
# 29  Africa  NaN  1994                   179.798731
# 30  Africa  NaN  1995                   186.889164
# 31  Africa  NaN  1996                   197.294306
# 32  Africa  NaN  1997                   206.047764
# 33  Africa  NaN  1998                   201.699962
# 34  Africa  NaN  1999                   199.795715
# 35  Africa  NaN  2000                   208.213584
# 36  Africa  NaN  2001                   214.431160
# ...

# %%
x=list(Africa.head(0))
x.remove('Year')
x.remove('Entity')
x.remove('Code')
x
# Out:
# ['Electricity from coal (TWh)',
#  'Electricity from gas (TWh)',
#  'Electricity from hydro (TWh)',
#  'Electricity from other renewables (TWh)',
#  'Electricity from solar (TWh)',
#  'Electricity from oil (TWh)',
#  'Electricity from wind (TWh)',
#  'Electricity from nuclear (TWh)']

# %%
Africa.describe()
# Out:
#               Year  Electricity from coal (TWh)  Electricity from gas (TWh)  \
# count    35.000000                    35.000000                   35.000000
# mean   2002.000000                   214.756396                  145.410151
# std      10.246951                    41.380072                  102.628099
# min    1985.000000                   139.514336                   27.926500
# 25%    1993.500000                   177.880568                   58.617500
# 50%    2002.000000                   222.897679                  115.952102
# 75%    2010.500000                   251.604683                  226.993056
# max    2019.000000                   262.470414                  340.472820
#
#        Electricity from hydro (TWh)  Electricity from other renewables (TWh)  \
# count                     35.000000                                35.000000
# mean                      84.308507                                 2.951156
# ...

# %%
Africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 20 to 54
# Data columns (total 11 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Entity                                   35 non-null     object
#  1   Code                                     0 non-null      object
#  2   Year                                     35 non-null     int64
#  3   Electricity from coal (TWh)              35 non-null     float64
#  4   Electricity from gas (TWh)               35 non-null     float64
#  5   Electricity from hydro (TWh)             35 non-null     float64
#  6   Electricity from other renewables (TWh)  35 non-null     float64
#  7   Electricity from solar (TWh)             35 non-null     float64
#  8   Electricity from oil (TWh)               35 non-null     float64
#  9   Electricity from wind (TWh)              35 non-null     float64
# ...

# %%
sns.jointplot(x='Year',y='Electricity from coal (TWh)',data=Africa)

# %%
year=Africa['Year']
Electricity_from_coal_(TWh)=Africa['Electricity from coal (TWh)']
plt.bar(year,Electricity_from_coal_(TWh))

# %%
sns.jointplot(x='Year',y='Electricity from solar (TWh)',data=Africa)
plt.title('ELECTRICITY FROM SOLAR')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sns.jointplot(x='Year',y='Electricity from oil (TWh)',data=Africa,kind='scatter')

# %%
sns.jointplot(data=Africa,y='Electricity from wind (TWh)',x='Year')

# %%
sns.jointplot(x='Year',y='Electricity from other renewables (TWh)',data=Africa)

# %%
sns.jointplot(x='Year',y='Electricity from nuclear (TWh)',data=Africa)

# %%
sns.jointplot(x='Year',y='Electricity from gas (TWh)',data=Africa)

# %%
sns.jointplot(x='Year',y='Electricity from hydro (TWh)',data=Africa)

# %%
#Electricity from solar from 2015
two_15=Africa[Africa['Year']==2015]['Electricity from solar (TWh)']
two_16=Africa[Africa['Year']==2016]['Electricity from solar (TWh)']
two_17=Africa[Africa['Year']==2017]['Electricity from solar (TWh)']
two_18=Africa[Africa['Year']==2018]['Electricity from solar (TWh)']
two_19=Africa[Africa['Year']==2019]['Electricity from solar (TWh)']
plt.figure(figsize=(20,10))
plt.pie([two_15,two_16,two_17,two_18,two_19])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-90b63ff6cfaa> in <module>
#       6 two_19=Africa[Africa['Year']==2019]['Electricity from solar (TWh)']
#       7 plt.figure(figsize=(20,10))
# ----> 8 plt.pie([two_15,two_16,two_17,two_18,two_19])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
sns.barplot(x='Year',y='Electricity from solar (TWh)',data=Africa)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Electricity from solar (TWh)'>
